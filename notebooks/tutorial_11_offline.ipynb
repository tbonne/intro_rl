# %% [markdown]
# # Tutorial 11: Offline learning

# %% [markdown]
# So far we've seen how to learn online, let's now see how we can learn offline.
#
# Note: this is different than the on-policy vs off-policy distinction.
